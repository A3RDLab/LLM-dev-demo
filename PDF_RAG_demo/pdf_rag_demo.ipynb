# %%
pip install pdfplumber numpy openai redis tabulate
# Out:
# Requirement already satisfied: pdfplumber in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (0.11.6)
# Requirement already satisfied: numpy in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: openai in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (1.93.1)
# Requirement already satisfied: redis in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (5.0.8)
# Requirement already satisfied: tabulate in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: pdfminer.six==20250327 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pdfplumber) (20250327)
# Requirement already satisfied: Pillow>=9.1 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pdfplumber) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pdfplumber) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pdfminer.six==20250327->pdfplumber) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pdfminer.six==20250327->pdfplumber) (43.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (2.11.9)
# Requirement already satisfied: sniffio in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: cffi>=1.12 in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /Users/limingyu/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber) (2.22)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cell 1: Import Libraries and Setup
import pdfplumber
import fitz  # PyMuPDF
from langchain.text_splitter import RecursiveCharacterTextSplitter
import pandas as pd
from openai import OpenAI
from redis import Redis
from redis.commands.search.field import VectorField, TextField
import numpy as np
import os

# OpenAI API setup
API_KEY = os.getenv("DASHSCOPE_API_KEY")  # 从环境变量读取 API Key
client = OpenAI(api_key=API_KEY, base_url="https://dashscope.aliyuncs.com/compatible-mode/v1")

# Redis setup
r = Redis()  # Assumes Redis is running on default host and port
INDEX_NAME = "electricity"
VECTOR_DIM = 1024
DISTANCE_METRIC = "COSINE"

pdf_path = "XM98633　世界500强电力企业比较分析报告（2023）(1).pdf"

# %%
# Cell 2: PDF Content Extraction
def extract_text_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        text = "".join(page.extract_text() or "" for page in pdf.pages)
    return text

def detect_table_pages(pdf_path):
    """Detect pages containing tables using pdfplumber."""
    table_pages = []
    with pdfplumber.open(pdf_path) as pdf:
        for page_num, page in enumerate(pdf.pages):
            if page.extract_tables():  # Check if page has tables
                table_pages.append(page_num)
    return table_pages

def save_page_as_image(pdf_path, page_num, output_path):
    """Save a PDF page as a PNG image."""
    pdf_document = fitz.open(pdf_path)
    page = pdf_document[page_num]
    pix = page.get_pixmap(matrix=fitz.Matrix(300/72, 300/72))  # 300 DPI
    pix.save(output_path)
    pdf_document.close()

def extract_images_from_pdf(pdf_path):
    """Extract standalone images from PDF (excluding table pages)."""
    pdf_document = fitz.open(pdf_path)
    images = []
    table_pages = set(detect_table_pages(pdf_path))  # Avoid extracting images from table pages
    for page_num in range(len(pdf_document)):
        # if page_num in table_pages:
        #     continue  # Skip pages with tables
        page = pdf_document[page_num]
        image_list = page.get_images(full=True)
        for img in image_list:
            xref = img[0]
            base_image = pdf_document.extract_image(xref)
            images.append(base_image["image"])
    pdf_document.close()
    return images

# Extract text and detect table pages
text = extract_text_from_pdf(pdf_path)
table_pages = detect_table_pages(pdf_path)
images = extract_images_from_pdf(pdf_path)

print(f"Extracted text length: {len(text)} characters")
print(f"Detected {len(table_pages)} pages with tables")
print(f"Extracted {len(images)} standalone images")
# Out:
# Extracted text length: 297067 characters
# Detected 77 pages with tables
# Extracted 2 standalone images

# %%
import base64
# Cell 3: Table Extraction with VL Model and Document Splitting
def split_text(text, chunk_size=1000, chunk_overlap=200):
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=["\n\n", "\n", " ", ""]
    )
    return splitter.split_text(text)
# Split text 
text_chunks = split_text(text)
print("First 20 text chunks:")
for chunk in text_chunks[:20]:
    print(chunk[:500] + "...")

def encode_image(image_path):
    """Encode image to base64."""
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")  


def extract_table_from_page_image(page_num):
    """Use VL model to extract table from page image in Markdown format."""
    image_path = f"table_page_{page_num}.png"
    save_page_as_image(pdf_path, page_num, image_path)
    base64_image = encode_image(image_path)
    
    try:
        response = client.chat.completions.create(
            model="qwen3-vl-30b-a3b-instruct",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "text",
                            "text": "Extract the table from the image and return it in Markdown format. If no table is present, return an empty string. Do not include additional explanations."
                        },
                        {
                            "type": "image_url",
                            "image_url": {"url": f"data:image/png;base64,{base64_image}"}
                        }
                    ]
                }
            ],
            temperature=0.2
        )
        table_markdown = response.choices[0].message.content
        return table_markdown if table_markdown.strip() else ""
    except Exception as e:
        print(f"Error processing table on page {page_num}: {str(e)}")
        return ""

# Process tables from detected table pages
table_chunks = []
for page_num in table_pages:
    table_markdown = extract_table_from_page_image(page_num)
    if table_markdown:
        table_chunks.append(table_markdown)
        print(f"Extracted table from page {page_num}: {table_markdown[:500]}...")

# 为所有保存的图片生成描述
image_descriptions = []
for i, image in enumerate(images):
    image_path = f"image_{i}.png"
    with open(image_path, "wb") as f:
        f.write(image)
    base64_image = encode_image(image_path)
    try:
        response = client.chat.completions.create(
            model="qwen3-vl-30b-a3b-instruct",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "text",
                            "text": "提取图片中的信息，需要精准描述，不要漏掉信息，但是也不需要额外解释。若图片为饼状图、折现图和柱状图等，请使用饼状图、折现图和柱状图等关键词，并以 json 格式返回。若图片为表格，请使用表格的关键词，并以 markdown 格式返回。若图片为架构图、流程图等，请使用架构图、流程图等关键词，并以 mermaid 格式返回。"
                        },
                        {
                            "type": "image_url",
                            "image_url": {"url": f"data:image/png;base64,{base64_image}"}
                        }
                    ]
                }
            ],
            temperature=0.2
        )
        description = response.choices[0].message.content
        image_descriptions.append(description)
        print(f"Generated description for image {i}: {description[:200]}...")
    except Exception as e:
        print(f"Error processing image {i}: {str(e)}")
        image_descriptions.append("")

print(f"Split text into {len(text_chunks)} chunks")
print(f"Converted {len(table_chunks)} tables to Markdown")
print(f"Generated {len(image_descriptions)} image descriptions")
# Out:
# First 20 text chunks:
# 8
# 4
# 3:
# 1
# 1
# 3
# -
# 3
# 0
# 3: 4 8 0 2 5 -
# 1 2
# 1 茹
# 3
# 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# ...
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# ...
# 印 张
# :
# 字 数 千字
# :
# 印 数 册
# :0001—0000
# 定 价 元
# :0.00
# 版 权 专 有 侵 权 必 究
# 本书如有印装质量问题 我社营销中心负责退换
# ,8
# 4
# 3:
# 1
# 1
# 3
# -
# 3
# 0
# 3: 4 8 0 2 5 -
# 1 2
# 1 茹
# 3
# 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 ...
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 声 究 明 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# ...
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 源
# 能
# 能
# 院
# 网
# 究
# 国
# 研
# 源
# 能
# 网
# 国8
# 4
# 3:
# 1
# 1
# 3
# -
# 3
# 0
# 3: 4 8 0 2 5 -
# 1 2
# 1 茹
# 3
# 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8...
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 编 委 所 会 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 主 任 欧阳源昌裕 研
# 能
# 能
# 源
# 3:...
# 指导专家 李成仁 尤培培8
# 4
# 3:
# 1
# 1
# 3
# -
# 3
# 0
# 3: 4 8 0 2 5 -
# 1 2
# 1 茹
# 3
# 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# ...
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 经过一年来的艰辛探索和不与 懈努力，国网能源院遵循智库本质规律院 ，思想
# 略
# 究
# 战
# 建院、理论强院，更加源坚定地踏上建设世界一流高端智库的新征研 ...
# 划
# 史
# 规
# 化改革等重点领域深化研究，围绕世界 5所0 0强电力企业、能源电力企业数字化 与
# 究
# 略
# 研
# 转型等特色领域深度解析。国网能划源院以“真研究问题”的态度，努力“研战究
# 源
# 规
# 能
# 真问题”。我们的期望是真诚与的，不求四平八稳地泛泛而谈，虽以一院 家之言，
# 略
# 究
# 战
# 但求激发业界共同思考源 ，在一些判断和结论上，一定有不成熟之研 处。对此，所
# 源
# 能
# 能
# 有参与报告研究编院 写的研究者，没有对鲜明的看法做模糊网 圆滑的处理，我们对
# 究
# 国
# 研
# 批评指正的源 期待同样是真诚的。
# 能
# 网
# 在我国能源发展面临严峻复杂内外部形势的关键时刻，国网能源院对“能
# 国
# 源的饭碗必须端在自己手里”，充满刻骨铭心的忧患意识和前所未有的责任
# 感，为中国能源事业当好思想先锋，是智库走出认知“舒适区”的勇敢担当。
# 我们深知，“积力之所举，则无不胜也；众智之所为，则无不成也。”国网能源
# 院愿与更多志同道合的有志之士，共同完成中国能源革命这份“国之大者”的
# 答卷。
# 国网能源研究院有限公司
# 2023年 11月8
# 4
# 3:
# 1
# 1
# 3
# -
# 3
# 0
# 3: 4 8 0 2 5 -
# 1 2
# 1 茹
# 3
# 3 - 一...
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 ...
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 源
# 能
# 能
# 院
# 网
# 究
# 国
# 研
# 源
# 能
# 网
# 国8
# 4
# 3:
# 1
# 1
# 3
# -
# 3
# 0
# 3: 4 8 0 2 5 -
# 1 2
# 1 茹
# 3
# 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 ...
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 ...
# 3
# 全
# : 4
# 球8 最大的 500
# 0 2 5
# -
# 1 2
# 家企业网的规模、盈利与行业分布情况，世界 500 强系统展示1 了全球经济发展 茹
# 3
# 国 3 - 一
# - 0 史
# 与产业结构变迁的故事，展现了大国崛起与企业竞争的5 方向。 国家的竞争看
# 0 2 所
# 茹
# 2 究
# 经济，经济的竞争看企业，企业的竞争突出表现在一批规模实力国际领先大 研
# 一
# 划
# 史
# 规
# 企业的较量。了解全球经济发展态势，观所 察不同类型行业发展动向， 是本书
# 与
# 究
# 略
# 研
# 成稿目的所在，并为政府部门、电力企业和社会各界提供有价值的决策参考。战
# 划
# 源
# 规
# 能
# 1996 年，中国上榜企业数与 量 4 家，国别排名为第 13 名；
# 院
# 2 019 年，
# 略
# 究
# 战
# 中国上榜企业有129家源，数量首次超过美国，国别排名位列第一。研能源电力行业
# 源
# 能
# 能
# 是国民经济的重要院 先行行业，是经济快速发展的先导。 网 2000 年中国上榜电
# 究
# 国
# 研
# 力企业仅有 1 家；2010 年 6 家，超越日本的 4 家； 2012 年达到最高的
# 源
# 能
# 8 家网； 2018 年至今保持在 7 家。中国企业在全球范围内实现跨越式...
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规...
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 从 2023 年上榜企业与世界经济发展趋势分析出
# 茹
# 发2 ，系统研究年度上榜企 究
# 研
# 一
# 划
# 业总体情况及主要特点，深度分析上榜电力企业在史 业务范围、经营情况动向和
# 规
# 所
# 与
# 趋势，先对世界 500 强上榜企业的基本情况究 进行了介绍，在对营业收入趋势、 略
# 研
# 战
# 划
# 源
# 入围门槛、国家竞争格局分析的基础规上，再分析榜单反映的中国企业发展、产
# 能
# 与
# 院
# 略
# 业结构转型、国有民营企业发展等情况；其次，介绍了上榜电力企业排名究 、国
# 战
# 研
# 源
# 别分布情况，比较分析上能榜电力企业的相关指标变化趋势；而后， 能 选 源 取了世界 3: 4 8
# 院
# 网 ...
# 研
# 战
# 划
# 源
# 源服务等相关业务。 规
# 能
# 与
# 院
# 略
# 限于作者水平及对资料掌握，难免还存在许多不足，期待读者们的究 批评指
# 战
# 研
# 源
# 源
# 正及宝贵建议，这将激能励我们研究的脚步走得更加踏实。
# 能
# 院
# 网
# 究
# 国
# 研
# 源
# 能
# 网
# 国8
# 4
# 3:
# 1
# 1
# 3
# -
# 3
# 0
# 3: 4 8 0 2 5 -
# 1 2
# 1 茹
# 3
# 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究...
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划...
# 划
# 源
# 1 1 3 榜单变迁与规国家地区竞争格局分析
# 能
# .. 与 ……………… 院 ……… 6
# 略
# 1 2 行业结构变迁与战经济发展动能分析 究
# . 源 …………………………研 …………… 8
# 源
# 1 2 1 能上榜企业行业分布情况
# 能
# ..院 ……………… 网 …………………… 8
# 究
# 1 2 2 上榜企业国别分布情况 国
# 研
# 源 .. …………………………………… 10
# 能 1 2 3 上榜企业人均营业收入情况
# 网 .. ……………………………… 12
# 国
# 1 3 2023年榜单排名变化分析
# . ……………………………………………… 16
# 1 3 1 榜单前 20名变化分析
# .. …………………………………… 16
# 1 3 2 榜单排名提升企业分析
# .. …………………………………… 17
# 1 3 3 榜单排名下降企业分析
# .. …………………………………… 20
# 1 3 4 新入榜企业分析
# .. …………………………………………… 22
# 1 3 5 退榜企业分析
# .. ……………………………………………… 24
# 2 2023年世界500强中国上榜企业情况 27
# 2 1 中国上榜...
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 ...
# 5
# 0 2 所
# 茹
# 2 究
# 研
# 一
# 划
# 史
# 规
# 所
# 与
# 究
# 略
# 研
# 战
# 划
# 源
# 规
# 能
# 与
# 院
# 略
# 究
# 战
# 研
# 源
# 能 源 4 8
# 能 3:
# 院
# 网 1
# 1
# 究 3
# 国 -
# 研 0 3
# 能 源 3: 4 8 0 2 5 -
# 1 2
# 网 1 茹
# 3
# 国 3 - 一
# - 0 史
# 5
# 0 2 所
# 2 1 2 新入榜企业分析
# 茹
# 2 究
# .. ……………… 一 …………………………… 30 研
# 划
# 2 1 3 退榜企业分析 史
# 规
# .. ……………所… ……………………………… 31 与
# 究
# 2 1 4 上榜企业盈亏变化分析 略
# 研
# .. 划 …………………………………… 32 战
# 源
# 2 2 中国上榜企业行业分析 规 能
# . …与…………………………………………… 院 … 36
# 略
# 2 2 1 金融行业分析 究
# 战
# .. 源 ………………………………………研……… 37
# 2 2 2 能源能行业分析 能 源 3: 4 8
# .. 院 ………………………………网……………… 38 1 1
# 究 3
# 2 2能 . 2 2 源. 3 4 研 互 车 联 辆 网 与 行 零 业 部 分 件 析 行业 … ...
# Extracted table from page 16: 图 1 - 2  2001—2023 年世界 500 强上榜门槛变化情况
# 资料来源：根据《财富》网站及世界银行数据资料整理。...
# Extracted table from page 17: | 排名 | 国家 | 上榜数量（家） |  |
# | :--- | :--- | :--- | :--- |
# | | | 2021年 | 2022年 |
# | 1 | 中国 | 143 | 145 |
# | 2 | 美国 | 122 | 124 |
# | 3 | 日本 | 53 | 47 |
# | 4 | 德国 | 27 | 28 |
# | 5 | 法国 | 26 | 25 |
# | 6 | 英国 | 22 | 18 |
# | 7 | 韩国 | 15 | 16 |
# | 8 | 瑞士 | 13 | 14 |
# | 9 | 加拿大 | 12 | 12 |
# | 10 | 荷兰 | 11 | 11 |
#
# | 排名 | 国别 | 平均净利润（亿美元） |  |
# | :--- | :--- | :--- | :--- |
# | | | 2021年 | 2022年 |
# | 1 | 英国 | 22.5 | 69.6 |
# | 2 | 美国 | 51.2 | 100.5 |
# | 3 | 瑞士 | 45.9 | 67.3 |
# | 4 | 加拿大 | 33.4 | 47.5 |
# | 5 | 荷兰 | -13.4 | 41.4 ...
# Extracted table from page 18: | 排名 | 国别 | 平均净利润 (亿美元) |  |  |
# | :--- | :--- | :--- | :--- | :--- |
# |  |  | 2021 年 | 2022 年 | 2023 年 |
# | 8 | 日本 | 32.0 | 35.6 | 32.0 |
# | 9 | 法国 | 13.2 | 48.5 | 31.5 |
# | 10 | 韩国 | 26.9 | 42.9 | 30.2 |
# | | 世界平均水平 | 33.0 | 62.0 | 58.0 |...
# Extracted table from page 19: | 行业名称 | 2021年 | 2022年 | 2023年 |
# | :--- | :--- | :--- | :--- |
# | 金融 | 118 | 110 | 101 |
# | 能源 | 64 | 72 | 82 |
# | 车辆与零部件 | 33 | 33 | 34 |
# | 医疗保健 | 32 | 28 | 26 |
# | 互联网 | 7 | 7 | 9 |
# | 行业名称 | 2021年 | 2022年 | 2023年 |
# | :--- | :--- | :--- | :--- |
# | 金融 | 23.0% | 20.2% | 18.5% |
# | 能源 | 15.2% | 18.8% | 23.3% |
# | 医疗保健 | 6.8% | 6.2% | 5.7% |
# | 车辆与零部件 | 7.8% | 7.6% | 7.5% |
# | 互联网 | 3.1% | 3.3% | 3.4% |
# | 行业名称 | 2021年 | 2022年 | 2023年 |
# | :--- | :--- | :--- | :--- |
# | 金融 | 37.6% | 31.5% | 23.9% |
# | 能源 | 0.1...
# Extracted table from page 20: | 序号 | 国别 | 2021年 | 2022年 | 2023年 |
# | :--- | :--- | :--- | :--- | :--- |
# | 1 | 中国 | 18 | 19 | 20 |
# | 2 | 美国 | 6 | 8 | 11 |
# | 3 | 德国 | 2 | 4 | 5 |
# | 4 | 韩国 | 2 | 3 | 5 |
# | 5 | 印度 | 4 | 4 | 4 |
# | 6 | 英国 | 4 | 4 | 4 |
# | 7 | 巴西 | 2 | 3 | 4 |
# | 8 | 日本 | 5 | 3 | 3 |
# | 9 | 法国 | 3 | 3 | 3 |
# | 10 | 西班牙 | 2 | 2 | 3 |...
# Extracted table from page 21: | 序号 | 国别 | 2021年 | 2022年 | 2023年 |
# | :--- | :--- | :--- | :--- | :--- |
# | 1 | 美国 | 31 | 30 | 31 |
# | 2 | 中国 | 26 | 24 | 21 |
# | 3 | 日本 | 11 | 11 | 11 |
# | 4 | 加拿大 | 8 | 6 | 6 |
# | 5 | 法国 | 5 | 5 | 5 |
# | 6 | 德国 | 5 | 5 | 4 |
# | 7 | 瑞士 | 5 | 5 | 4 |
# | 8 | 巴西 | 3 | 3 | 4 |
# | 9 | 意大利 | 4 | 3 | 3 |
# | 10 | 韩国 | 3 | 3 | 3 |
# | 序号 | 国别 | 2021年 | 2022年 | 2023年 |
# | :--- | :--- | :--- | :--- | :--- |
# | 1 | 中国 | 7 | 8 | 9 |
# | 2 | 日本 | 10 | 8 | 7 |
# | 3 | 德国 | 6 | 6 | 7 |
# | 4 | 韩国 | 3 | 3 | 3 |...
# Extracted table from page 22: | 序号 | 国别 | 2021年 | 2022年 | 2023年 |
# | :--- | :--- | :--- | :--
|
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | 5 | 工商银行 | 银行：商业储蓄 | 中国石油 | 炼油 | 台积公司 | 半导体、电子元件 |
# | 6 | 建设银行 | 银行：商业储蓄 | 国家电网 | 公用设施 | 腾讯 | 互联网服务和零售 |
# | 7 | 中国石化 | 炼油 | 中国移动 | 电信 | 中国石油 | 炼油 |
# | 8 | 国泰人寿 | 人寿与健康保险（股份） | 交通银行 | 银行：商业储蓄 | 招商银行 | 银行：商业储蓄 |
# | 9 | 农业银行 | 银行：商业储蓄 | 中国石化 | 炼油 | 中国海油 | 采矿、原油生产 |
# | 10 | 中粮集团 | 贸易 | 中国海油 | 采矿、原油生产 | 中国移动 | 电信 |
#
# 资料来源：根据《财富》网站相关资料整理。
#
# 表 2 - 8 2003、2013、2023 年榜单中国上榜亏损企业
#
# | 排名 | 2003 年 | 所在行业 | 201...
# Extracted table from page 46: | 年份 | 2001 | 2002 | 2003 | 2004 | 2005 | 2006 | 2007 | 2008 | 2009 | 2010 | 2011 | 2012 | 2013 | 2014 | 2015 | 2016 | 2017 | 2018 | 2019 | 2020 | 2021 | 2022 | 2023 |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | 单位(家) | 6 | 6 | 5 | 9 | 10 | 12 | 14 | 14 | 17 | 19 | 25 | 28 | 29 | 29 | 32 | 34 | 32 | 29 | 29 | 30 | 33 | 32 | 32 |...
# Error processing table on page 49: Connection error.
# Extracted table from page 50: | 年度 | 收入利润率 |  | 收入增长率 |  |
# | :--- | :--- | :--- | :--- | :--- |
# | | 中国 | 美国 | 中国 | 美国 |
# | 2019 | 17.4% | 17.1% | 37.2% | 30.6% |
# | 2020 | 16.1% | 20.5% | 20.5% | 21.8% |
# | 2021 | 18.7% | 23.3% | 27.7% | 24.0% |
# | 2022 | 17.6% | 3.0% | 32.8% | 33.4% |
# | 2023 | 5.9% | 17.1% | 10.7% | 25.2% |...
# Error processing table on page 54: Connection error.
# Extracted table from page 57: | 表2-12 | 地方国有企业行业及上榜企业数量分布情况 |
# | :--- | :--- |
# | 行业分布 | 2023年 | 2019年 |
# | 采矿、原油生产 | 6 | 11 |
# | 车辆与零部件 | 3 | 3 |
# | 多元化金融 | 3 | — |
# | 房地产 | 1 | 1 |
# | 工程与建筑 | 5 | — |
# | 工业机械 | 1 | — |
# | 化学品 | 1 | — |
# | 建材、玻璃 | 1 | 1 |
# | 金属产品 | 8 | 1 |
# | 贸易 | 4 | 1 |
# | 批发：保健 | 1 | — |
# | 人寿与健康保险（股份） | 1 | 1 |
# | 银行：商业储蓄 | 2 | 1 |
# | 运输及物流 | 2 | — |
# | 制药 | 1 | — |...
# Extracted table from page 61: | 排名 | 公司名称 | 行业 | 营业收入增长率(%) | 利润增长率(%) | 净利率(%) | 净资产收益率(%) |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | 2 | 国家电网 | 公用设施 | 0.7 | -30 | 1.4 | 0.8 |
# | 4 | 中国石油 | 炼油 | -25.1 | 3 | 1.6 | 0.7 |
# | 5 | 中国石化 | 炼油 | -30.3 | -8.7 | 2.2 | 1.8 |
# | 13 | 中国建筑 | 工程与建筑 | 13.9 | 7.4 | 1.5 | 1.1 |
# | 16 | 中国平安 | 人寿与健康保险（股份） | 3.9 | -4.1 | 10.8 | 1.4 |
# | 20 | 工商银行 | 银行：商业储蓄 | 3.2 | 1.3 | 25 | 0.9 |
# | 22 | 鸿海精密 | 电子、电气设备 | 5.3 | 7.3 | 1.9 | 2.6 |
# | 25 | 建设银行 | 银行：商业储蓄 | 8.3 | 1.7 | 22.8 | 0.9 |
# | 29 | 农业...
# Error processing table on page 62: Request timed out.
# Error processing table on page 65: Connection error.
# Error processing table on page 66: Connection error.
# Error processing table on page 69: Connection error.
# Extracted table from page 70: | 项目 | 2022 年 (百万欧元) | 2021 年 (百万欧元) |
# | :--- | :--- | :--- |
# | 陆上风力发电业务 | 2232 | 2330 |
# | 水质/生物质/天然气 | 1830 | 1315 |
# | 供应与贸易业务 | 31 959 | 19 296 |
# | 其他业务 | — | 4 |
# | 煤/核能 | 944 | 899 |
#
# | 项目 | 2022 年 (百万韩元) | 2021 年 (百万韩元) |
# | :--- | :--- | :--- |
# | 营业收入 | 71 257 863 | 60 673 587 |
# | 输配电业务 | 68 951 546 | 59 660 600 |
# | 核能发电业务 | 10 386 091 | 9 324 391 |
# | 非核能发电业务 | 41 944 339 | 25 928 596 |
# | 工厂维护和工程服务 | 2 975 062 | 2 805 785 |
# | 其他业务 | 2 750 231 | 2 018 997 |...
# Error processing table on page 71: Connection error.
# Error processing table on page 78: Connection error.
# Extracted table from page 79: | 基本指标 | 一级指标（比例） | 二级指标 |
# | :--- | :--- | :--- |
# | 经营实力指标 | | 市值（20%） |
# | | | 营业收入（20%） |
# | | | EBITDA（20%） |
# | 技术经济指标 | | 综合线损率 |
# | | | 清洁能源占比 |
# | | | 单位资产售电量 |...
# Extracted table from page 80: | 公司 | 盈利回报 | 资产运营 | 风险防控 | 持续发展 | 加法分 | 乘法分 |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | 伊维尔德罗拉 | 77.00 | 57.28 | 59.19 | 78.95 | 69.09 | 68.39 |
# | 意大利电力 | 67.57 | 84.22 | 54.92 | 55.21 | 64.65 | 64.58 |
# | 美国南方电力 | 75.59 | 69.89 | 56.31 | 54.91 | 64.46 | 64.43 |
# | 国家电网 | 50.45 | 91.76 | 70.83 | 55.74 | 65.13 | 63.74 |
# | 巴登—符滕堡州能源公司 | 63.33 | 85.17 | 45.33 | 60.12 | 62.40 | 62.39 |
# | 意昂集团 | 63.58 | 93.16 | 51.36 | 47.26 | 62.36 | 61.99 |
# | 葡萄牙能源 | 71.75 | 50.05 | 46.08 | 77.89 | 62.53 ...
# Extracted table from page 81: | 公司 | 盈利回报 | 资产运营 | 风险防控 | 持续发展 | 加法分 | 乘法分 |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | 法国电力 | 22.91 | 60.21 | 36.20 | 33.63 | 36.37 | 35.15 |
# | 中位数 | 63.33 | 78.79 | 53.17 | 48.95 | 61.08 | 60.35 |...
# Error processing table on page 82: Connection error.
# Error processing table on page 83: Connection error.
# Extracted table from page 84: | 公司 | 综合线损率 |  | 清洁能源占比 |  | 单位资产售电量 |  | 得分 |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | | 指标（%） | 得分 | 指标（%） | 得分 | 指标（%） | 得分 | |
# | 美国南方电力 | 5.52 | 4.00 | 30.00 | 2.00 | 1.56 | 5.33 | 3.78 |
# | 爱克斯龙 | 5.89 | 3.33 | 44.92 | 4.67 | 0.68 | 0.67 | 2.89 |
# | 中位数 | 5.10 | 5.33 | 46.85 | 5.33 | 1.56 | 5.33 | 5.33 |
# | 注：1. 单位资产售电量指标单位为 kW•h/美元。 |  |  |  |  |  |  |  |
# | 2. 列表按照技术经济指标得分排序。 |  |  |  |  |  |  |  |
#
# | 公司 | 规模实力指标 |  | 经营绩效指标 |  | 技术经济指标 |  | 世界一流企业评价 |  |
# | :--- | :--- | :...
# Extracted table from page 85: | 公司 | 规模实力指标 |  | 经营绩效指标 |  | 技术经济指标 |  | 世界一流企业评价 |  |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | | 得分 | 排名 | 得分 | 排名 | 得分 | 排名 | 指数 | 排名 |
# | 中部电力 | 81.77 | 13 | 52.54 | 11 | 4.22 | 11 | 47.19 | 11 |
# | 关西电力 | 81.86 | 12 | 47.71 | 12 | 5.56 | 6 | 44.61 | 12 |
# | 东京电力 | 81.68 | 14 | 42.15 | 13 | 5.33 | 7 | 39.76 | 13 |
# | 法国电力 | 84.96 | 9 | 35.15 | 15 | 4.67 | 9 | 34.53 | 14 |
# | 韩国电力 | 75.92 | 15 | 35.68 | 14 | 6.67 | 3 | 33.75 | 15 |
# | 中位数 | 86.02 | — | 60.35 | — | 5.33 | ...
# Extracted table from page 93: | 业务单元 | 财资中心 | 支付工厂 | 外部供应商 |
# | :--- | :--- | :--- | :--- |
# | 子公司 | 1 | | 法国 |
# | 子公司 | 2 | | 荷兰 |
# | 子公司 | 3 | | 澳大利亚 |
# | | | | 中国 |
# | | | | 俄罗斯 |
# | | | | 南非 |
# | | | | ...... |...
# Extracted table from page 94: | | 资产类业务 | | 费用类业务 | |
# | :--- | :--- | :--- | :--- | :--- |
# | | 设备与销售融资 | 股权融资 | 项目融资 | 投资管理 | 保险管理 | 司库 |
# | | 新业务融资 | 基建融资 | 基建融资 | 公司年金 | 公司业务与财产保险 | 现金管理和支付 |
# | | 应收账款 | 风险项目 | 出口信贷 | 年金顾问 | 员工保险 | 风险管理和融资 |
# | | 信贷合租 | | 融资咨询 | | 保险代理与顾问 | 资本市场 |
# | | 融资租赁 | | 担保 | | | 金融市场 |
# | | | | 资产证券化 | | | 信息技术管理 |...
# Extracted table from page 98: 图 4 - 8 埃克森美孚组织架构图...
# Error processing table on page 103: Connection error.
# Error processing table on page 112: Request timed out.
# Extracted table from page 113: | 2023 年排名 | 2022 年排名 | 公司名称 | 国别 | 收入 | 利润 |
# | :--- | :--- | :--- | :--- | :--- | :--- |
# |

# | :--- | :--- | :--- | :--- | :--- | :--- |
# | 248 | 255 | 美国国际集团 | 美国 | 56 437 | 10 276 |
# | 249 | 244 | Talanx 公司 | 德国 | 56 029 | 1233 |
# | 250 | 270 | 俄罗斯联邦储蓄银行 | 俄罗斯 | 55 877 | 3959 |
# | 251 | 465 | 巴西银行 | 巴西 | 55 870 | 5353 |
# | 252 | 233 | 中国电子科技集团有限公司 | 中国 | 55 848 | 2665 |
# | 253 | 320 | 美国运通公司 | 美国 | 55 625 | 7514 |
# | 254 | 201 | 力拓集团 | 英国 | 55 554 | 12 420 |
# | 255 | 283 | 大众超级市场公司 | 美国 | 54 942 | 2918 |
# | 256 | 269 | 中国能源建设集团有限公司 | 中国 | 54 890 | ...
# Error processing table on page 122: Connection error.
# Error processing table on page 123: Connection error.
# Error processing table on page 124: Connection error.
# Error processing table on page 125: Connection error.
# Error processing table on page 126: Connection error.
# Error processing table on page 127: Request timed out.
# Error processing table on page 128: Connection error.
# Error processing table on page 129: Connection error.
# Error processing table on page 130: Connection error.
# Extracted table from page 131: | 2023 年排名 | 2022 年排名 | 公司名称 | 营业收入 (百万美元) | 利润 (百万美元) | 资产 (百万美元) | 股东权益 (百万美元) | 员工数 (万人) |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | 74 | 70 | 中国华润有限公司 | 121 643 | 4662 | 331 830 | 45 826 | 37.99 |
# | 76 | 85 | 国家能源投资集团有限责任公司 | 121 584 | 5699 | 281 587 | 71 647 | 31.08 |
# | 83 | 89 | 中国南方电网有限责任公司 | 113 674 | 1516 | 166 026 | 60 382 | 27.12 |
# | 84 | 68 | 上海汽车集团股份有限公司 | 110 612 | 2396 | 143 552 | 40 485 | 15.49 |
# | 86 | 81 | 中国邮政集团有限公司 | 110 271 | 4897 | 2 131 968 | 71 671 | 75....
# Error processing table on page 132: Connection error.
# Error processing table on page 133: Request timed out.
# Error processing table on page 134: Request timed out.
# Error processing table on page 135: Connection error.
# Error processing table on page 136: Request timed out.
# Error processing image 0: Connection error.
# Error processing image 1: Connection error.
# Split text into 372 chunks
# Converted 43 tables to Markdown
# Generated 2 image descriptions

# %%
from tqdm.notebook import tqdm  # Jupyter专用进度条

# Cell 4: Vectorization (with progress bars)
def get_embedding(text, model="text-embedding-v3"):
    if not text.strip():
        return None
    response = client.embeddings.create(
        input=text[:8192*2],  # Truncate to approximate token limit
        model=model,
        dimensions=VECTOR_DIM
    )
    return response.data[0].embedding

# Generate embeddings with progress bars
print("Generating text embeddings...")
text_embeddings = [get_embedding(chunk) for chunk in tqdm(text_chunks, desc="Text chunks")]

print("\nGenerating table embeddings...")
table_embeddings = [get_embedding(chunk[0:8192]) for chunk in tqdm([c for c in table_chunks if c], desc="Tables")]

print("\nGenerating image embeddings...")
image_embeddings = [get_embedding(desc[0:8192]) for desc in tqdm(image_descriptions, desc="Images")]

# %%
# Cell 5: Data Storage in Redis
# Define index schema
md_embedding_field = VectorField(
    "md_embedding", "FLAT",
    {"TYPE": "FLOAT32", "DIM": VECTOR_DIM, "DISTANCE_METRIC": DISTANCE_METRIC}
)
content_field = TextField("content")
type_field = TextField("type")
fields_for_index = [content_field, type_field, md_embedding_field]

# Create index
try:
    r.ft(INDEX_NAME).create_index(fields=fields_for_index)
    print(f"Index '{INDEX_NAME}' created successfully")
except Exception as e:
    print(f"Index creation failed: {e}")

# Store data
def store_data(chunks, embeddings, data_type):
    for i, (chunk, embedding) in enumerate(zip(chunks, embeddings)):
        key = f"{INDEX_NAME}:{data_type}:{i}"
        mapping_data = {
            "md_embedding": np.array(embedding, dtype=np.float32).tobytes(),
            "content": chunk,
            "type": data_type
        }
        r.hset(key, mapping=mapping_data)

store_data(text_chunks, text_embeddings, "text")
store_data(table_chunks, table_embeddings, "table")
store_data(image_descriptions, image_embeddings, "image")

print("Data stored in Redis successfully")

# %%
import numpy as np
import json
from redis.commands.search.query import Query
# Search
user_question = "工商银行2024年海外布局？"
# user_question = "工商银行为什么被成为”宇宙行“？"

# Helper functions
def json_gpt(input: str):
    completion = client.chat.completions.create(
        model="qwen2.5-7b-instruct",
        messages=[
            {"role": "system", "content": "Output only valid JSON"},
            {"role": "user", "content": input},
        ],
        temperature=0.2,
    )

    text = completion.choices[0].message.content
    parsed = json.loads(text)

    return parsed


HA_INPUT = f"""
You are a financial report analysis assistant.
You have access to a search API that returns relevant sections from a financial report.
Generate a search query by extracting key words from the user's question.

User question: {user_question}

Format: {{"searchQuery": "search query"}}
"""
query_str = json_gpt(HA_INPUT)["searchQuery"]
print(query_str)

query_embedding = client.embeddings.create(input=query_str, model="text-embedding-v3", dimensions=1024, encoding_format="float")
query_vec = np.array(query_embedding.data[0].embedding, dtype=np.float32).tobytes()
# Prepare the query
k_nearest = 3  # Retrieve top 3 relevant chunks
query_base = (Query(f"*=>[KNN {k_nearest} @md_embedding $vec as score]").sort_by("score").return_fields("score", "content", "type").dialect(2))
query_param = {"vec": query_vec}
try:
    query_results = r.ft(INDEX_NAME).search(query_base, query_param).docs
    print(f"\nRetrieved {len(query_results)} results:")
    for i, doc in enumerate(query_results):
        print(f"\n--- Result {i+1} ---")
        print(f"Type: {doc.type}")
        print(f"Score: {doc.score}")
        print(f"Content (first 200 chars): {doc.content[:200]}...")
except Exception as e:
    print(f"Error executing vector query: {e}")
    query_results = []
# Prepare context for the LLM
context = "\n\n".join([doc.content for doc in query_results])

# %%
system_prompt = "你是一个金融报告分析专家。请根据搜索结果回答用户提问，注意，请务必首先依赖搜索结果，而不是你自己已有的知识。如果搜索结果不包含能够回答用户提问的信息，你可以说“抱歉，我无法回答这个问题”。"
messages = [{"role": "system", "content": system_prompt},
            {"role": "user", "content": "用户提问：" + user_question},
            {"role": "user", "content": "搜索结果：" + context}]
response = client.chat.completions.create(
                    messages=messages,
                    model="qwen2.5-32b-instruct", #"qwen-max",
                    max_tokens=1000
                )
print(response.choices[0].message.content)
